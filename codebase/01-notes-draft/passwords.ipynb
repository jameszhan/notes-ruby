# %%
a = [98, 101, 110, 95, 53, 50, 49, 32, 35, 32, 100, 97, 109, 
  117, 108, 128, 97, 110, 103, 32, 35, 32, 122, 97, 110, 103, 
  99, 104, 111, 110, 103, 98, 105, 110, 49, 50, 51, 64, 49, 
  54, 51, 46, 99, 111, 109, 13, 10]

str = a.pack('C*')
p str.encoding
str
# Out:
# #<Encoding:ASCII-8BIT>
# "ben_521 # damul\x80ang # zangchongbin123@163.com\r\n"

# %%
puts str.force_encoding('GBK').encode('UTF-8')
# Out:
# ben_521 # damul€ang # zangchongbin123@163.com

# %%
a = [99, 102, 121, 95, 115, 111, 104, 111, 116, 32, 35, 32, 67, 90, 38, 113, 46, 255, 55, 54, 32, 
    35, 32, 99, 122, 113, 49, 56, 56, 64, 49, 54, 51, 46, 99, 111, 109, 13, 10]
str = a.pack('C*')
str.force_encoding('ISO8859-1').encode('UTF-8')
# Out:
# "cfy_sohot # CZ&q.ÿ76 # czq188@163.com\r\n"

# %%
a = [128, 183, 234, 136, 246, 215, 247, 145, 242, 161, 235, 9, 49, 51, 49, 52, 50, 49, 13, 10]
str = a.pack('C*')
str.force_encoding('GBK').encode('UTF-8')
# Out:
# "€逢場作戲‰\t131421\r\n"

# %%
a = [255, 9, 103, 97, 109, 101, 115, 111, 102, 116, 13, 10]
str = a.pack('C*')
str.force_encoding('ISO8859-1').encode('UTF-8')
# Out:
# "ÿ\tgamesoft\r\n"

# %%
a = [161, 234, 68, 105, 209, 212, 214, 220, 100, 101, 205, 199, 
183, 207, 128, 9, 119, 111, 97, 105, 110, 105, 49, 51, 49, 
52, 13, 10]
str = a.pack('C*')
str.force_encoding('GBK').encode('UTF-8')
# Out:
# "￡Di言周de颓废€\twoaini1314\r\n"

# %%
a = [68, 181, 247, 128, 187, 170, 192, 246, 9, 49, 57, 57, 50, 48, 55, 50, 48, 56, 13, 10]
str = a.pack('C*')
str.force_encoding('GBK').encode('UTF-8')
# Out:
# "D调€华丽\t199207208\r\n"

# %%
a = [206, 168, 162, 229, 161, 162, 255, 161, 161, 166, 199, 105, 
9, 119, 111, 97, 105, 97, 111, 103, 117, 97, 105, 13, 10]
str = a.pack('C*')
str.force_encoding('ISO8859-1').encode('UTF-8')
# Out:
# "Î¨¢å¡¢ÿ¡¡¦Çi\twoaiaoguai\r\n"

# %%
a = [98, 51, 51, 107, 53, 121, 103, 104, 101, 115, 9, 255, 13, 10]
str = a.pack('C*')
str.force_encoding('ISO8859-1').encode('UTF-8')
# Out:
# "b33k5yghes\tÿ\r\n"

# %%
a = [165, 219, 128, 169, 240, 165, 163, 211, 133, 108, 111, 118, 
  101, 9, 49, 51, 54, 54, 54, 50, 53, 50, 50, 51, 55, 13, 10]
str = a.pack('C*')
s = str.force_encoding('ISO8859-1').encode('UTF-8')
p s
login_id, _ = s.split(/\t/, 2)
sql = %(psql security -c "SELECT * FROM passwords WHERE login_id = '#{login_id.strip}'")
puts sql
`#{sql}`
# Out:
# "¥Û\u0080©ð¥£Ólove\t13666252237\r\n"
# psql security -c "SELECT * FROM passwords WHERE login_id = '¥Û©ð¥£Ólove'"
# "    id    |         created_at         |         updated_at         |  password   |        login_id         | email | domain |                              sha256                              |               md5                \n----------+----------------------------+----------------------------+-------------+-------------------------+-------+--------+------------------------------------------------------------------+----------------------------------\n 23436276 | 2018-03-27 22:37:40.175703 | 2018-03-27 22:37:40.175703 | 13666252237 | ¥Û\\u0080©ð¥£Ó\\u0085love |       | 7k7k   | 7ab8a77c61c8d2228bda1cce366fc138b22de21baab4bb969bf95a3b919ca580 | 91cae43820c83f65838a1606634764fa\n(1 row)\n\n"

# %%
a = [120, 105, 51, 40, 36, 86, 80, 104, 116, 9, 178, 233, 206, 222, 180, 203, 200, 203, 255, 13, 10]
str = a.pack('C*')
s = str.force_encoding('GBK').encode('UTF-8')
p s
login_id, _ = s.split(/\t/, 2)
sql = %(psql security -c "SELECT * FROM passwords WHERE login_id = '#{login_id}'")
puts sql
`#{sql}`
# Out:
# Encoding::InvalidByteSequenceError: "\xFF" on GBK
# <main>:2:in `encode'
# <main>:2:in `<main>'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/backend.rb:72:in `eval'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/backend.rb:72:in `block in eval'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/backend.rb:55:in `eval_with_magic'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/backend.rb:71:in `eval'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/backend.rb:13:in `eval'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/kernel.rb:87:in `execute_request'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/kernel.rb:47:in `dispatch'
# /usr/local/rvm/gems/ruby-2.5-head/bundler/gems/iruby-a2d7f8bcd676/lib/iruby/kernel.rb:37:in `run'
# ...

# %%
a = [165, 219, 128, 169, 240, 165, 163, 211, 133, 166, 216, 9, 54, 53, 55, 48, 49, 57, 57, 56, 13, 10]
str = a.pack('C*')
str.force_encoding('utf-8').encode('UTF-8')
# Out:
# "\xA5ۀ\xA9\xF0\xA5\xA3Ӆ\xA6\xD8\t65701998\r\n"

# %%
arrays = [
  [207, 224, 183, 234, 128, 198, 188, 203, 174, 9, 49, 51, 53, 50, 52, 54, 13, 10],
  [128, 184, 223, 208, 203, 128, 9, 97, 98, 99, 51, 52, 53, 13, 10],
  [89, 79, 85, 128, 9, 97, 98, 49, 50, 51, 52, 13, 10],
[165, 164, 210, 212, 191, 149, 165, 219, 128, 215, 82, 9, 49, 51, 57, 52, 50, 50, 52, 54, 49, 51, 53, 13, 10],
[165, 219, 128, 165, 163, 211, 133, 215, 212, 188, 186, 9, 56, 51, 49, 48, 48, 56, 13, 10],
[215, 207, 201, 171, 128, 197, 206, 9, 55, 55, 50, 51, 54, 55, 50, 13, 10],
[128, 108, 97, 105, 114, 101, 9, 49, 52, 49, 51, 13, 10],
[128, 128, 9, 56, 55, 48, 48, 49, 13, 10],
[206, 210, 128, 66, 117, 9, 56, 55, 48, 48, 49, 13, 10]
  ]

arrays.each_with_index do |array, i|
  str = array.pack('C*')
  s = str.force_encoding('GBK').encode('UTF-8')
  p "#{i}: #{s}"
  login_id, _ = s.split(/\t/, 2)
  sql = %(psql security -c "SELECT * FROM passwords WHERE login_id = '#{login_id}'")
  puts sql
  puts `#{sql}`
end
# Out:
# "0: 相逢€萍水\t135246\r\n"
# psql security -c "SELECT * FROM passwords WHERE login_id = '相逢€萍水'"
#     id    |         created_at         |         updated_at         | password | login_id  | email | domain |                              sha256                              |               md5
# ----------+----------------------------+----------------------------+----------+-----------+-------+--------+------------------------------------------------------------------+----------------------------------
#  24408265 | 2018-03-27 22:48:39.803327 | 2018-03-27 22:48:39.803327 | 135246   | 相逢€萍水 |       | 7k7k   | cfb789f892fdf2a45ab1bc1f046932df431a7708165393e0f13fab2c9267c0eb | d437df002f7a5c8555c107af8a643977
# (1 row)
#
#
# "1: €高兴€\tabc345\r\n"
# psql security -c "SELECT * FROM passwords WHERE login_id = '€高兴€'"
# ...

# %%
`psql security -c "SELECT * FROM passwords WHERE password = '²éÎÞ´ËÈËÿ'"`
# Out:
# "    id    |         created_at         |         updated_at         | password  | login_id  | email | domain |                              sha256                              |               md5                \n----------+----------------------------+----------------------------+-----------+-----------+-------+--------+------------------------------------------------------------------+----------------------------------\n 21910246 | 2018-03-27 22:19:10.956945 | 2018-03-27 22:19:10.956945 | ²éÎÞ´ËÈËÿ | xi3($VPht |       | 7k7k   | 2a4523f4e710c814639989bc5acb239e2d3b2df1af198285b71d1dcfd0172a5c | 1cbb10de81c0fad8dbb2b25702ab75d4\n 22914479 | 2018-03-27 22:31:33.438547 | 2018-03-27 22:31:33.438547 | ²éÎÞ´ËÈËÿ |           |       | 7k7k   | 2a4523f4e710c814639989bc5acb239e2d3b2df1af198285b71d1dcfd0172a5c | 1cbb10de81c0fad8dbb2b25702ab75d4\n(2 rows)\n\n"

# %%
arrays = [
